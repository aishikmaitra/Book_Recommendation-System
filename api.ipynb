# %%
from openai import OpenAI
import pandas as pd

# %%
OPENAPI="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"
client=OpenAI(api_key=OPENAPI)

# %%
df=pd.read_csv(r"C:\Users\aishi\Videos\HAT\archive (4)\Books.csv")
df
# Out:
# C:\Users\aishi\AppData\Local\Temp\ipykernel_8604\1690968056.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\aishi\Videos\HAT\archive (4)\Books.csv")
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
blist=df["Book-Title"].head(100)
b=[]

# %%
for j in range(0,5):
    k=0
    for i in range(k,k+5):
        completions=client.chat.completions.create(
        model="gpt-3.5-turbo-1106",
        messages=[
            {"role":"system","content":"You are a helpful assistant"},
            {"role":"user","content":"Give me the brief summary of the book "+blist[i]}
            ]
        )
        message=completions.choices[0].message.content
        b.append(message)
        print(b[k:k+5])
    k+=5
#print(message)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 k=0
#       3 for i in range(k,k+5):
# ----> 4     completions=client.chat.completions.create(
#       5     model="gpt-3.5-turbo-1106",
#       6     messages=[
#       7         {"role":"system","content":"You are a helpful assistant"},
#       8         {"role":"user","content":"Give me the brief summary of the book "+blist[i]}
#       9         ]
#      10     )
#      11     message=completions.choices[0].message.content
#      12     b.append(message)
#
# File c:\Users\aishi\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# ...

# %%
b
# Out:
# ['"Classical Mythology" is a comprehensive overview of the myths from the ancient civilizations of Greece and Rome. The book delves into the stories of the gods, heroes, and monsters of classical mythology, providing insight into the cultural significance and enduring influence of these tales. With engaging narratives and scholarly analysis, the book offers a rich exploration of the timeless myths that continue to captivate and inspire readers today.',
#  '"Clara Callan" is a novel by Richard B. Wright that tells the story of two sisters living in the 1930s. The book is presented as a series of journal entries and letters written by Clara and Nora Callan. The story explores their lives, relationships, and aspirations, offering a glimpse into the challenges and opportunities faced by women during that time period. Their contrasting experiences and perspectives illuminate the complexities of family, identity, and the pursuit of happiness.',
# ...
